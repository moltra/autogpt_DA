# %%
import requests
import json
import pandas as pd
import re
import nltk

# %%
# importing `config.py` to access its variables
from config import github_token_value

# %%
	pd.options.display.max_columns = 250 #Changes the number of columns diplayed (default is 20)
	pd.options.display.max_rows = 250 #Changes the number of rows diplayed (default is 60)
	pd.options.display.max_colwidth = 250 #Changes the number of characters in a cell so that the contents don't get truncated (default is 50)

# %%
import requests

# Set the API endpoint URL
url = "https://api.github.com/repos/{owner}/{repo}/issues"

# Set the owner and repo variables
owner = "Significant-Gravitas"
repo = "Auto-GPT"

# Set the authentication token (if required)
token = github_token_value

# Set the query parameters for the API request
params = {
    "state": "open",  # retrieve all issues, including closed ones
    "per_page": 100,  # retrieve up to 100 issues per page
    "page": 1  # start with the first page of results
}

# %%
issues = []

while True:
    response = requests.get(url.format(owner=owner, repo=repo), params=params, auth=(token, ""))

    if response.status_code != 200:
        print("Error retrieving issues from GitHub API")
        break

    page_issues = response.json()
    issues += page_issues

    if "Link" not in response.headers:
        break

    link_header = response.headers["Link"]
    next_url = None
    for link in link_header.split(","):
        if "rel=\"next\"" in link:
            next_url = link.split(";")[0][1:-1]
            break

    if next_url is None:
        break

    print(params)    
    params["page"] += 1

print(f"Retrieved {len(issues)} issues from GitHub")

# Print the response headers
print("Response Headers:")
for key, value in response.headers.items():
    print(f"{key}: {value}")
# Out:
# Retrieved 87 issues from GitHub
# Response Headers:
# Server: GitHub.com
# Date: Thu, 27 Apr 2023 17:23:44 GMT
# Content-Type: application/json; charset=utf-8
# Transfer-Encoding: chunked
# Cache-Control: public, max-age=60, s-maxage=60
# Vary: Accept, Accept-Encoding, Accept, X-Requested-With
# ETag: W/"19361a167f4822a99d783c52f3f98d343d3dd12a63f50a8ae35de6d0dc1523e7"
# X-GitHub-Media-Type: github.v3; format=json
# Link: <https://api.github.com/repositories/614765452/issues?state=open&per_page=100&page=5>; rel="prev", <https://api.github.com/repositories/614765452/issues?state=open&per_page=100&page=1>; rel="first"
# x-github-api-version-selected: 2022-11-28
# X-RateLimit-Limit: 60
# X-RateLimit-Remaining: 59
# X-RateLimit-Reset: 1682619824
# X-RateLimit-Used: 1
# X-RateLimit-Resource: core
# Access-Control-Expose-Headers: ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset
# Access-Control-Allow-Origin: *
# Strict-Transport-Security: max-age=31536000; includeSubdomains; preload
# X-Frame-Options: deny
# X-Content-Type-Options: nosniff
# X-XSS-Protection: 0
# Referrer-Policy: origin-when-cross-origin, strict-origin-when-cross-origin
# Content-Security-Policy: default-src 'none'
# Content-Encoding: gzip
# X-GitHub-Request-Id: 9728:47E0:A93C5E:15BBCED:644AAF9F

# %%
# Export the resulting JSON to a file
with open("github-issues.json", "w") as outfile:
    json.dump(issues, outfile)

print("Exported JSON to github-issues.json")
# Out:
# Exported JSON to github-issues.json

# %%
issues_df = pd.json_normalize(issues)

print(issues_df.head())
# Out:
#                                                                      url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/785  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/778
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/766
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/765
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/758
#
#                                                repository_url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT
#
#                                                                             labels_url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/785/labels{/name}  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/778/labels{/name}
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/766/labels{/name}
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/765/labels{/name}
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/758/labels{/name}
#
#                                                                      comments_url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/785/comments  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/778/comments
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/766/comments
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/765/comments
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/758/comments
#
#                                                                      events_url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/785/events  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/778/events
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/766/events
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/765/events
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/758/events
#
#                                                       html_url          id
# 0  https://github.com/Significant-Gravitas/Auto-GPT/issues/785  1662127683  \
# 1  https://github.com/Significant-Gravitas/Auto-GPT/issues/778  1662004403
# 2    https://github.com/Significant-Gravitas/Auto-GPT/pull/766  1661721834
# 3    https://github.com/Significant-Gravitas/Auto-GPT/pull/765  1661719629
# 4    https://github.com/Significant-Gravitas/Auto-GPT/pull/758  1661678378
#
#                node_id  number
# 0   I_kwDOJKSTjM5jEg5D     785  \
# 1   I_kwDOJKSTjM5jECyz     778
# 2  PR_kwDOJKSTjM5N--HC     766
# 3  PR_kwDOJKSTjM5N-9pt     765
# 4  PR_kwDOJKSTjM5N-1LX     758
#
#                                                                                              title
# 0                          Prompt Seeder - After setting up roal and goals, generate a seed prompt  \
# 1                           "str is not valid UTF-8: surrogates not allowed" after "y -10" command
# 2                                           Add 1/0 as an alternative to y/n for non-english users
# 3  🚀 REST API: AGI can Create, Start and Stop multiple Autonomous Agents (Monitoring coming soon)🚀
# 4                                                              Add knowledge cutoff date to prompt
#
#                                                                                                                                                                                                                                                       labels
# 0                                                                                                                                                                                                                                                         []  \
# 1  [{'id': 5272676193, 'node_id': 'LA_kwDOJKSTjM8AAAABOkanYQ', 'url': 'https://api.github.com/repos/Significant-Gravitas/Auto-GPT/labels/bug', 'name': 'bug', 'color': 'd73a4a', 'default': True, 'description': 'Something isn't working'}, {'id': 54015...
# 2  [{'id': 5400185961, 'node_id': 'LA_kwDOJKSTjM8AAAABQeBMaQ', 'url': 'https://api.github.com/repos/Significant-Gravitas/Auto-GPT/labels/conflicts', 'name': 'conflicts', 'color': 'FBCA04', 'default': False, 'description': 'Automatically applied to P...
# 3  [{'id': 5381931159, 'node_id': 'LA_kwDOJKSTjM8AAAABQMnAlw', 'url': 'https://api.github.com/repos/Significant-Gravitas/Auto-GPT/labels/needs%20discussion', 'name': 'needs discussion', 'color': '0e8a16', 'default': False, 'description': 'To be disc...
# 4  [{'id': 5400185961, 'node_id': 'LA_kwDOJKSTjM8AAAABQeBMaQ', 'url': 'https://api.github.com/repos/Significant-Gravitas/Auto-GPT/labels/conflicts', 'name': 'conflicts', 'color': 'FBCA04', 'default': False, 'description': 'Automatically applied to P...
#
#   state  locked  assignee
# 0  open   False       NaN  \
# 1  open   False       NaN
# 2  open   False       NaN
# 3  open   False       NaN
# 4  open   False       NaN
#
#                                                                                                                                                                                                                                                    assignees
# 0                                                                                                                                                                                                                                                         []  \
# 1                                                                                                                                                                                                                                                         []
# 2  [{'login': 'Pwuts', 'id': 12185583, 'node_id': 'MDQ6VXNlcjEyMTg1NTgz', 'avatar_url': 'https://avatars.githubusercontent.com/u/12185583?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Pwuts', 'html_url': 'https://github.com/Pwuts', '...
# 3                                                                                                                                                                                                                                                         []
# 4                                                                                                                                                                                                                                                         []
#
#   milestone  comments            created_at            updated_at closed_at
# 0      None         0  2023-04-11T09:47:42Z  2023-04-11T09:49:19Z      None  \
# 1      None         6  2023-04-11T08:27:14Z  2023-04-22T19:25:43Z      None
# 2      None         8  2023-04-11T03:46:19Z  2023-04-26T20:54:37Z      None
# 3      None        21  2023-04-11T03:42:51Z  2023-04-22T23:26:09Z      None
# 4      None         3  2023-04-11T02:38:46Z  2023-04-22T23:26:09Z      None
#
#   author_association active_lock_reason
# 0        CONTRIBUTOR               None  \
# 1               NONE               None
# 2               NONE               None
# 3        CONTRIBUTOR               None
# 4               NONE               None
#
#                                                                                                                                                                                                                                                         body
# 0  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now Auto-GPT does not provide any feedback on the goals and role etc.\r\n\r\nTo make sure it understood the assignment, it would be much better for ...  \
# 1  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\n1. Run Auto-GPT as Docker image via VS Code.\r\n2. Provide goals for Auto-GPT.\r\n3. Write "y" command few times.\r\n4. Write "y -10" command f...
# 2  <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 3  <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 4  ### Background\r\nThis change was made to the `ai_config.py` file #185. However, based on a suggestion, the knowledge cutoff was directly added to the `prompt.txt` file. This aims to provide metadata to the AI, enhancing its search coordination a...
#
#                                                                      timeline_url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/785/timeline  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/778/timeline
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/766/timeline
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/765/timeline
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/758/timeline
#
#   performed_via_github_app state_reason          user.login   user.id
# 0                     None         None           Wladastic  11997278  \
# 1                     None         None              coolk8  13322564
# 2                     None         None  Francisco-Montanez  32565971
# 3                     None         None       merwanehamadi   9652976
# 4                     None         None            Romelium  96741133
#
#            user.node_id                                       user.avatar_url
# 0  MDQ6VXNlcjExOTk3Mjc4  https://avatars.githubusercontent.com/u/11997278?v=4  \
# 1  MDQ6VXNlcjEzMzIyNTY0  https://avatars.githubusercontent.com/u/13322564?v=4
# 2  MDQ6VXNlcjMyNTY1OTcx  https://avatars.githubusercontent.com/u/32565971?v=4
# 3  MDQ6VXNlcjk2NTI5NzY=   https://avatars.githubusercontent.com/u/9652976?v=4
# 4          U_kgDOBcQnDQ  https://avatars.githubusercontent.com/u/96741133?v=4
#
#   user.gravatar_id                                         user.url
# 0                            https://api.github.com/users/Wladastic  \
# 1                               https://api.github.com/users/coolk8
# 2                   https://api.github.com/users/Francisco-Montanez
# 3                        https://api.github.com/users/merwanehamadi
# 4                             https://api.github.com/users/Romelium
#
#                            user.html_url
# 0           https://github.com/Wladastic  \
# 1              https://github.com/coolk8
# 2  https://github.com/Francisco-Montanez
# 3       https://github.com/merwanehamadi
# 4            https://github.com/Romelium
#
#                                           user.followers_url
# 0           https://api.github.com/users/Wladastic/followers  \
# 1              https://api.github.com/users/coolk8/followers
# 2  https://api.github.com/users/Francisco-Montanez/followers
# 3       https://api.github.com/users/merwanehamadi/followers
# 4            https://api.github.com/users/Romelium/followers
#
#                                                        user.following_url
# 0           https://api.github.com/users/Wladastic/following{/other_user}  \
# 1              https://api.github.com/users/coolk8/following{/other_user}
# 2  https://api.github.com/users/Francisco-Montanez/following{/other_user}
# 3       https://api.github.com/users/merwanehamadi/following{/other_user}
# 4            https://api.github.com/users/Romelium/following{/other_user}
#
#                                                     user.gists_url
# 0           https://api.github.com/users/Wladastic/gists{/gist_id}  \
# 1              https://api.github.com/users/coolk8/gists{/gist_id}
# 2  https://api.github.com/users/Francisco-Montanez/gists{/gist_id}
# 3       https://api.github.com/users/merwanehamadi/gists{/gist_id}
# 4            https://api.github.com/users/Romelium/gists{/gist_id}
#
#                                                          user.starred_url
# 0           https://api.github.com/users/Wladastic/starred{/owner}{/repo}  \
# 1              https://api.github.com/users/coolk8/starred{/owner}{/repo}
# 2  https://api.github.com/users/Francisco-Montanez/starred{/owner}{/repo}
# 3       https://api.github.com/users/merwanehamadi/starred{/owner}{/repo}
# 4            https://api.github.com/users/Romelium/starred{/owner}{/repo}
#
#                                           user.subscriptions_url
# 0           https://api.github.com/users/Wladastic/subscriptions  \
# 1              https://api.github.com/users/coolk8/subscriptions
# 2  https://api.github.com/users/Francisco-Montanez/subscriptions
# 3       https://api.github.com/users/merwanehamadi/subscriptions
# 4            https://api.github.com/users/Romelium/subscriptions
#
#                                  user.organizations_url
# 0           https://api.github.com/users/Wladastic/orgs  \
# 1              https://api.github.com/users/coolk8/orgs
# 2  https://api.github.com/users/Francisco-Montanez/orgs
# 3       https://api.github.com/users/merwanehamadi/orgs
# 4            https://api.github.com/users/Romelium/orgs
#
#                                           user.repos_url
# 0           https://api.github.com/users/Wladastic/repos  \
# 1              https://api.github.com/users/coolk8/repos
# 2  https://api.github.com/users/Francisco-Montanez/repos
# 3       https://api.github.com/users/merwanehamadi/repos
# 4            https://api.github.com/users/Romelium/repos
#
#                                                     user.events_url
# 0           https://api.github.com/users/Wladastic/events{/privacy}  \
# 1              https://api.github.com/users/coolk8/events{/privacy}
# 2  https://api.github.com/users/Francisco-Montanez/events{/privacy}
# 3       https://api.github.com/users/merwanehamadi/events{/privacy}
# 4            https://api.github.com/users/Romelium/events{/privacy}
#
#                                           user.received_events_url user.type
# 0           https://api.github.com/users/Wladastic/received_events      User  \
# 1              https://api.github.com/users/coolk8/received_events      User
# 2  https://api.github.com/users/Francisco-Montanez/received_events      User
# 3       https://api.github.com/users/merwanehamadi/received_events      User
# 4            https://api.github.com/users/Romelium/received_events      User
#
#    user.site_admin
# 0            False  \
# 1            False
# 2            False
# 3            False
# 4            False
#
#                                                                      reactions.url
# 0  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/785/reactions  \
# 1  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/778/reactions
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/766/reactions
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/765/reactions
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/issues/758/reactions
#
#    reactions.total_count  reactions.+1  reactions.-1  reactions.laugh
# 0                      1             0             0                0  \
# 1                      0             0             0                0
# 2                      0             0             0                0
# 3                     74            28             0                7
# 4                      0             0             0                0
#
#    reactions.hooray  reactions.confused  reactions.heart  reactions.rocket
# 0                 1                   0                0                 0  \
# 1                 0                   0                0                 0
# 2                 0                   0                0                 0
# 3                 7                   0               10                13
# 4                 0                   0                0                 0
#
#    reactions.eyes  draft assignee.login  assignee.id      assignee.node_id
# 0               0    NaN            NaN          NaN                   NaN  \
# 1               0    NaN            NaN          NaN                   NaN
# 2               0  False          Pwuts   12185583.0  MDQ6VXNlcjEyMTg1NTgz
# 3               9  False            NaN          NaN                   NaN
# 4               0  False            NaN          NaN                   NaN
#
#                                     assignee.avatar_url assignee.gravatar_id
# 0                                                   NaN                  NaN  \
# 1                                                   NaN                  NaN
# 2  https://avatars.githubusercontent.com/u/12185583?v=4
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
#
#                          assignee.url         assignee.html_url
# 0                                 NaN                       NaN  \
# 1                                 NaN                       NaN
# 2  https://api.github.com/users/Pwuts  https://github.com/Pwuts
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
#
#                          assignee.followers_url
# 0                                           NaN  \
# 1                                           NaN
# 2  https://api.github.com/users/Pwuts/followers
# 3                                           NaN
# 4                                           NaN
#
#                                       assignee.following_url
# 0                                                        NaN  \
# 1                                                        NaN
# 2  https://api.github.com/users/Pwuts/following{/other_user}
# 3                                                        NaN
# 4                                                        NaN
#
#                                    assignee.gists_url
# 0                                                 NaN  \
# 1                                                 NaN
# 2  https://api.github.com/users/Pwuts/gists{/gist_id}
# 3                                                 NaN
# 4                                                 NaN
#
#                                         assignee.starred_url
# 0                                                        NaN  \
# 1                                                        NaN
# 2  https://api.github.com/users/Pwuts/starred{/owner}{/repo}
# 3                                                        NaN
# 4                                                        NaN
#
#                          assignee.subscriptions_url
# 0                                               NaN  \
# 1                                               NaN
# 2  https://api.github.com/users/Pwuts/subscriptions
# 3                                               NaN
# 4                                               NaN
#
#                 assignee.organizations_url
# 0                                      NaN  \
# 1                                      NaN
# 2  https://api.github.com/users/Pwuts/orgs
# 3                                      NaN
# 4                                      NaN
#
#                          assignee.repos_url
# 0                                       NaN  \
# 1                                       NaN
# 2  https://api.github.com/users/Pwuts/repos
# 3                                       NaN
# 4                                       NaN
#
#                                    assignee.events_url
# 0                                                  NaN  \
# 1                                                  NaN
# 2  https://api.github.com/users/Pwuts/events{/privacy}
# 3                                                  NaN
# 4                                                  NaN
#
#                          assignee.received_events_url assignee.type
# 0                                                 NaN           NaN  \
# 1                                                 NaN           NaN
# 2  https://api.github.com/users/Pwuts/received_events          User
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
#
#   assignee.site_admin
# 0                 NaN  \
# 1                 NaN
# 2               False
# 3                 NaN
# 4                 NaN
#
#                                                        pull_request.url
# 0                                                                   NaN  \
# 1                                                                   NaN
# 2  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/pulls/766
# 3  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/pulls/765
# 4  https://api.github.com/repos/Significant-Gravitas/Auto-GPT/pulls/758
#
#                                        pull_request.html_url
# 0                                                        NaN  \
# 1                                                        NaN
# 2  https://github.com/Significant-Gravitas/Auto-GPT/pull/766
# 3  https://github.com/Significant-Gravitas/Auto-GPT/pull/765
# 4  https://github.com/Significant-Gravitas/Auto-GPT/pull/758
#
#                                             pull_request.diff_url
# 0                                                             NaN  \
# 1                                                             NaN
# 2  https://github.com/Significant-Gravitas/Auto-GPT/pull/766.diff
# 3  https://github.com/Significant-Gravitas/Auto-GPT/pull/765.diff
# 4  https://github.com/Significant-Gravitas/Auto-GPT/pull/758.diff
#
#                                             pull_request.patch_url
# 0                                                              NaN  \
# 1                                                              NaN
# 2  https://github.com/Significant-Gravitas/Auto-GPT/pull/766.patch
# 3  https://github.com/Significant-Gravitas/Auto-GPT/pull/765.patch
# 4  https://github.com/Significant-Gravitas/Auto-GPT/pull/758.patch
#
#    pull_request.merged_at
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
print(issues_df[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(issues_df[1])
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 1

# %%
issues_df.size
print(len(issues_df.index))
issues_df.to_csv('issues_df.csv')
# Out:
# 87

# %%
# iterating the columns
for col in issues_df.columns:
    print(col)
# Out:
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# active_lock_reason
# body
# timeline_url
# performed_via_github_app
# state_reason
# user.login
# user.id
# user.node_id
# user.avatar_url
# user.gravatar_id
# user.url
# user.html_url
# user.followers_url
# user.following_url
# user.gists_url
# user.starred_url
# user.subscriptions_url
# user.organizations_url
# user.repos_url
# user.events_url
# user.received_events_url
# user.type
# user.site_admin
# reactions.url
# reactions.total_count
# reactions.+1
# reactions.-1
# reactions.laugh
# reactions.hooray
# reactions.confused
# reactions.heart
# reactions.rocket
# reactions.eyes
# draft
# assignee.login
# assignee.id
# assignee.node_id
# assignee.avatar_url
# assignee.gravatar_id
# assignee.url
# assignee.html_url
# assignee.followers_url
# assignee.following_url
# assignee.gists_url
# assignee.starred_url
# assignee.subscriptions_url
# assignee.organizations_url
# assignee.repos_url
# assignee.events_url
# assignee.received_events_url
# assignee.type
# assignee.site_admin
# pull_request.url
# pull_request.html_url
# pull_request.diff_url
# pull_request.patch_url
# pull_request.merged_at

# %%
# copy dataframe
issues_title=issues_df.copy(deep=True)
issues_body=issues_df.copy(deep=True)

# %%
issues_body = issues_body[['number', 'body']]

# %%
print(issues_body)
# Out:
#     number
# 0      785  \
# 1      778
# 2      766
# 3      765
# 4      758
# 5      753
# 6      749
# 7      727
# 8      718
# 9      691
# 10     660
# 11     623
# 12     605
# 13     594
# 14     589
# 15     567
# 16     556
# 17     531
# 18     528
# 19     527
# 20     526
# 21     514
# 22     513
# 23     511
# 24     510
# 25     506
# 26     503
# 27     500
# 28     495
# 29     492
# 30     453
# 31     442
# 32     430
# 33     399
# 34     393
# 35     389
# 36     386
# 37     375
# 38     368
# 39     364
# 40     356
# 41     348
# 42     347
# 43     346
# 44     344
# 45     340
# 46     335
# 47     324
# 48     319
# 49     316
# 50     305
# 51     304
# 52     298
# 53     296
# 54     292
# 55     289
# 56     286
# 57     285
# 58     280
# 59     276
# 60     270
# 61     264
# 62     251
# 63     232
# 64     227
# 65     221
# 66     213
# 67     203
# 68     201
# 69     182
# 70     181
# 71     172
# 72     171
# 73     151
# 74     150
# 75     148
# 76     146
# 77     114
# 78      85
# 79      56
# 80      38
# 81      25
# 82      21
# 83      15
# 84      11
# 85       6
# 86       5
#
#                                                                                                                                                                                                                                                          body
# 0   ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now Auto-GPT does not provide any feedback on the goals and role etc.\r\n\r\nTo make sure it understood the assignment, it would be much better for ...
# 1   ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\n1. Run Auto-GPT as Docker image via VS Code.\r\n2. Provide goals for Auto-GPT.\r\n3. Write "y" command few times.\r\n4. Write "y -10" command f...
# 2   <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 3   <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 4   ### Background\r\nThis change was made to the `ai_config.py` file #185. However, based on a suggestion, the knowledge cutoff was directly added to the `prompt.txt` file. This aims to provide metadata to the AI, enhancing its search coordination a...
# 5   ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAdd `1/0` as alternative to `y/n`\n\n### Examples 🌈\n\nSo in\r\n`Continue (y/n)` and `Enter \'y\' to authorise command, \'y -N\' to run N continuous commands, \'n\' t...
# 6   Bitcoin handling for payments via bitcoin_utils.py\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to ...
# 7   ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nCurrently Auto-GPT writes the entire python or text file at once. If the file gets beyond a few paragraphs this starts to cause issues often time causing json parsing...
# 8   **EDIT: Please delete this PR as #697 seems to be a better solution**\r\n\r\nFixes #701 Credits belong to @Moomero\r\n\r\n### Background\r\nINVALID JSON errors happen very commonly. \r\n\r\n### Changes\r\nThis fix filters better and reduces the a...
# 9   Add additional clarification to error message as this is the first check of the model name.  An alternative approach would be to add a verification of the model before this is called.\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increa...
# 10  https://github.com/Torantulino/Auto-GPT/issues/656#issue-1660550311\r\n\r\nFix from updated line 20 from \r to \n\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the ...
# 11  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\n1. Set API Keys for OpenAI, Pinecone, and Eleven Labs, then set the smart model to gpt-3.5-turbo\r\n2. Start AutoGPT with the --gpt3only option\r\n3. Promp...
# 12  ### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, prior discussions, or links to relevant issues. -->\r\n\r\nThe aim of this PR is to make the use of Redis Stack beginner friendly ...
# 13                             Added some extra instructions to improve PR quality by addressing common pitfalls.\r\n\r\nI hope this will improve the quality of PRs and our efficiency in merging and reviewing them.\r\n\r\n@Torantulino what do you think?
# 14  ### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, prior discussions, or links to relevant issues. -->\r\nFork and clone instructions are not clear.\r\n\r\n### Changes\r\n\r\n<!-- D...
# 15                                                 ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nThat would be simply great instead of using OpenAI\n\n### Examples 🌈\n\n_No response_\n\n### Motivation 🔦\n\n_No response_
# 16  ### Background\r\n\r\n![image](https://user-images.githubusercontent.com/34168009/230755671-ddc951c8-3566-4426-8587-35a74d7f3186.png)\r\n\r\nIt's possible for your connection being closed causes AutoGPT to crash.\r\n\r\n### Changes\r\n\r\nWraps t...
# 17  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nbeable to understand the context of images\n\n### Examples 🌈\n\nlook on open ais showcase of gpt4 images context understanding and explainion\n\n### Motivation 🔦\n\nw...
# 18  ### System Awareness\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nBefore going out to look at the internet \r\nIt would be helpful if upon activation the AI took inventory of the system it was on and shared the ava...
# 19  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nI have locally installed Auto-GPT \r\nwithin the auto_gpt_workspace - I cloned the Auto-GPT repo\r\nI then asked the AI to look up the outstanding issues and begin to...
# 20  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nI wrote a python file that i am trying to get auto-gpt to utilize to scrape some data off the internet. To run the file, it requires the use of an argumen...
# 21  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nWhen crawling the web to do market research, a lot of links are sometimes just pdf documents. It would be great if Auto GPT had an inherent ability to parse those pdf...
# 22  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nAsk for Auto GPT to create a image, using sd in the .env\n\n### Current behavior 😯\n\nThe Auto-GPT got this error when tried to use generate_image command:...
# 23  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nAI Name: GameDev-GPT\r\n\r\nDescribe your AI's role:  For example, 'an AI designed to autonomously develop and run businesses with the sole goal of increas...
# 24  ### Background\r\n\r\nBig branch build on top of https://github.com/Torantulino/Auto-GPT/pull/372 (Redis implementation and memory refactor).\r\n\r\nWe need to improve modularity to scale the project so I created AutoGPT wrapper with the old main...
# 25  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAuto-GPT needs an inherent understanding of itself and the ability to connect with other Auto-GPT instances for collaboration. Once we get them talking they can figur...
# 26  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nReplace Google Search by an agency (coop of agents) to search both Google and pinecone memory from a prompt sent by autogpt to this agency \r\n\r\nUses multiple insta...
# 27  [![workerB](https://img.shields.io/endpoint?url=https%3A%2F%2Fworkerb.linearb.io%2Fv2%2Fbadge%2Fprivate%2FU2FsdGVkX12X34Yic5DPfPZec1mXyQl10i0d9YJs%2Fcollaboration.svg%3FcacheSeconds%3D60)](https://workerb.linearb.io/v2/badge/collaboration-page?ma...
# 28  ### Design Document\r\n https://docs.google.com/document/d/1pHtgK4OaFxy2POColR4nYJ3wemU4XLTEoxTLQunzaU0/edit?usp=sharing\r\n\r\n### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, pr...
# 29  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nCommand Generate Image "generate_image" is a great addition. However the image size is hardcoded,\r\nI propose the issue to make it controllable with an optional argu...
# 30  ### Background\r\n\r\nFelt I need more optionality at start-up: load last settings, load setting file from your history or create new settings. The need came out of running different "missions" with changes to the settings and prompts. Wanted an ...
# 31  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nLooking at Microsoft’s Jarvis and the improvement seen with refinement (where GPT is prompted after it’s response “did you do the last task correctly?”). Perhaps we c...
# 32  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAny thoughts on enabling auto-GPT to pick up where it left off after an error? It has done some noble work, but has never fully completed the tasks I've set for it be...
# 33  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nI'm not sure how to reproduce it, i've had it running trying to make a crossword generator for a while.\n\n### Current behavior 😯\n\nThe PLAN: output shows...
# 34  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nMy current challenge is it's hard to know how much it's costing me to run autoGPT for each session (for OPEN_AI in particular)\r\n\r\nIf I knew how much i...
# 35  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nUnsure, it randomly seems to produce this error. I've even given instructions that if the AI failed to parse the output then to reformat the input to a man...
# 36  ### Background\r\n\r\nI am using Auto-GPT search, browse and summarize code in another project and using this parallelization of single url summarization and summarizing multiple urls. \r\nAs most of the processing is IO bound I find this approac...
# 37  ### Background\r\n\r\nDevs and aspiring contributors frequently have dependency conflicts when trying to clone the repo and build dependencies for the first time. \r\n\r\nAdding an alternate requirements file:\r\n- Removes package versions, allow...
# 38  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\nN/A\r\n\r\n### Current behavior 😯\r\n\r\nAuto-GPT has limited test coverage, which makes it difficult to ensure that changes to the codebase do...
# 39  ### Background\r\nHey everyone, I saw some Twitter posts about people being able to install react apps and what not but didn't seem to be able to get it to work on my end. So, I took a stab at creating a module for working with react apps and add...
# 40  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nI'm wondering whether Auto-GPT, even if it's written in Python, could support other programming languages as well, since GPT is able to program in multiple ones.\r\n\...
# 41  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nImplement "Fully Air-Gapped Offline Auto-GPT" functionality that allows users to run Auto-GPT without any internet connection, relying on local models and...
# 42  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nLocal Models (LLaMA & its finetunes) now work in a fork of Auto-GPT, including with Pinecone Embeddings. See https://github.com/Torantulino/Auto-GPT/issue...
# 43  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\n1. Attach to a VirtualBox instance, give AI a default OS like ubuntu\r\n2. if AI decide to use computer: enter "screenshot-mouse/keyboard" loop, also ai can dump file...
# 44                                                                      I've added one other env variable to set tha pinecone index/table name from envs; previously it was a bit unclear how to configure pinecone and where does it get the table name from
# 45                                                                                                                                                                                                       Just for consistency, cost me ~5 seconds at setup 🤖
# 46                                                                                                                                                                                                                                                       None
# 47  Test, and make the needed changes to get this to work.\r\n\r\nIt may or may not work, there are still more things needed to get it working, but from testing it may work.\r\n\r\nPossible Suggestions:\r\n\r\n1) Combine the output of the custom mode...
# 48  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nUpgraded to latest version with Pinecone. Prompts that worked great yesterday now break constantly. Throwing the error:\r\n\r\nFailed to parse AI output, a...
# 49  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nIdea:\r\n\r\n- Add a `ai_settings` directory to contain yaml files in the form of `last_run_ai_settings.yaml`. This way we could create and share interesting or succe...
# 50  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nSummarize and then critique current approach and progress. I have done x,y and z. Progress p has been made toward the goal. Changing the approach is/is not warranted....
# 51  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now I am experimenting with a Wikidata Query command in auto-gpt on my repo: https://github.com/stefangrotz/Auto-GPT-Wikidata\r\n\r\nFeel free to jo...
# 52  So there are a few issues here that going into a larger design discussion so for now I re-worked the prompts, added a bit more option there and created a fallback output if the LLM decides to break format. \r\n\r\nThis also removes the LLM cycle ...
# 53  error During Requirement .txt execution \r\n\r\nOn raspberry pi 4b 8GB with Raspbian OS \r\n\r\nPython 3.7.3\r\npip3 install -r requirements.txt\r\n\r\nerror: \r\n  Could not find a version that satisfies the requirement python-dotenv==1.0.0 (fro...
# 54  Congratulation for this amazing Project \r\ni have local p retrained model through https://github.com/oobabooga/text-generation-webui\r\nusing their API in this format "\r\n\r\nimport requests\r\n\r\nresponse = requests.post("http://127.0.0.1:786...
# 55                                                                                                                                                                                                                                            Addresses #270
# 56  I've encountered the same problem as #101. GPT Thinks that `evaluate_code` will execute python:\r\n```\r\nCODEREVIEW-GPT THOUGHTS: Let's find some code to review and suggest improvements.\r\nREASONING: We need to search for files with common code...
# 57  Fixed the json_parser.py error by making chatgpt fix itself\r\n\r\ndef fix_and_parse_json(json_str: str, try_to_fix_with_gpt: bool = True):\r\n    json_schema = """\r\n    {\r\n    "command": {\r\n        "name": "command name",\r\n        "args"...
# 58  AutoGPT should be able to read GitHub issues, update its goals based on them, and respond as a commenter\n\n\nAutoGPT when you see this, please do the following: \n1. Find/get/create a list of all the usernames who forked this repo (Torantulino/A...
# 59  To improve this project, here are some suggestions:\r\n\r\nModularize the code: Separate the functions in commands.py into different modules based on their functionality. For example, you can create a module for file operations, another for memor...
# 60                                                                                                             If a user has multiple organizations linked to their OpenAI account they will be unable to use keys generated through different organizations.
# 61  You can use a class to encapsulate the behavior of the agents and remove the need for global variables. This will make the code more organized, and way less prone to error.\r\nYou can add error handing in case the API call to Open AI fails or the...
# 62  Hi,\r\n\r\nfeel free to close this again rightaway since I dont know if the is an issue at all.\r\n\r\nIn some demos when the AI creates a new instance, the new instance speaks with a female voice, an the conversation between the AI is easy to fo...
# 63  It appears that Auto-GPT is not working well with other character encodings. I am trying to use it on information written in Portuguese (Brazilian Portuguese) and sometimes it complains about "string indices must be integers" - I believe it is be...
# 64                                   AutoGPT was getting confused, and causing errors because it thought the keys for memory_ovr were strings instead of an integer. This better explains that the keys are actually indexes, which helps prevent this error.
# 65                                                                                                                        Moved all the ai functionality into one place - ai_functions.py.\r\n\r\nTo test: Run it for a little while, you will see no errors.
# 66                                                                                                                                                           I moved the memory functionality into it's own file, and made it a singleton. Works as expected.
# 67  Hi there,\r\nsince this is an evolving system, i think we should use collective experience, and like a tesla fleet, get better collectively\r\n### Proposal: Record Insights, Submit for review, Use Pinecone Embeddings\r\nif a task is requested and...
# 68  This change fixes an issue where we were writing the `string` as the `key` in `commit_memory`\r\n\r\nit re-designs perm memory to be a dictionary (key, value store) that seems to be a better fit for our use-case\r\n\r\n\r\ntest logs:\r\n\r\n```\r...
# 69  raise error.APIConnectionError(\r\nopenai.error.APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Cannot connect t...
# 70  Work in progress, but im Trying to give auto gpt a way to build, manage, and run command inside docker containers.\r\n\r\nThe goal are : \r\n- No need tp set up any dev environnment for Auto-Gpt to work\r\n- A way for Auto-GPT to run any commands...
# 71  Taking inspiration from the method that Langchain uses to instruct the bot on which tool to use, I've fleshed out each of the tools with a brief description to help the bot make a better decision. In testing it appears to work well and the bot se...
# 72                                                                                                                                                                                      What do you think of an option like this to enable language support ?
# 73  Hi there! Looked around the open issues but haven't seen this suggestion yet\r\n\r\nFirstly, I'd like to know that whatever is running is always logged (maybe that's addressed somewhere)\r\n\r\nSecondly , I'd like a "Cautious" Monitored Continuou...
# 74  ## Summary\r\n\r\nI propose a new feature called "Semi-Active Mode," which enables the AI to run in a semi-automated manner, seeking user assistance when it encounters uncertainty, confusion, or ambiguity. This feature combines the benefits of Co...
# 75  Love the project, wondering if you'd like to use vocode's interfaces for speech synthesis!\r\n- ports the existing ElevenLabs, gTTS, and StreamElements integrations\r\n- enables Azure voices: https://azure.microsoft.com/en-us/products/cognitive-s...
# 76  Hey everyone, I've been working on integrating Redis and a separate terminal-based CLI client with AutoGPT to enable asynchronous question-and-answer user interactions. This is just a draft PR, so any feedback or contributions are more than welco...
# 77  GPT already knows way too much stuff, there's no need to search the web for every little sub-task that comes up. For example, if you ask GPT what the rules for texas hold'em poker are, it knows and is able to detail it without any issues. When us...
# 78  This PR focuses on enhancing the file operations module by implementing the following changes:\r\n\r\n* Replacing the `os` and `os.path` modules with the `pathlib module`, which simplifies file and directory operations while providing better read...
# 79  Create a new command to dynamically expand capabilities.\r\n\r\n1. Identify a capability gap. e.g. if current weather/stock prices cannot be obtained from current Auto-GPT capabilities \r\n2. Provide a static list of known API libraries (or disco...
# 80  AutoGPT keeps exceeding the token limit by like 100 tokens every time I use it before it finishes it's task and can't handle the error\r\nTraceback (most recent call last):\r\n  File "/root/Auto-GPT/scripts/main.py", line 199, in <module>\r\n    ...
# 81  You can modify the code to accept a config file as input, and read the Chosen_Model flag to select the appropriate AI model. Here's an example of how to achieve this:\r\n\r\nCreate a sample config file named config.ini:\r\n\r\n[AI]\r\nChosen_Mode...
# 82                                                                                      It doesn't work?\r\n\r\n<img width="1440" alt="image" src="https://user-images.githubusercontent.com/6225438/229346042-a8687d08-8c4d-4094-8da4-b2300fb51732.png">\r\n
# 83  ## Idea 💡\r\nThe **ULTIMATE** achievement for this project would be if Auto-GPT was able to recursively improve itself. That, after-all, is how AGI is predicted by many to come about. \r\n\r\n## Suggestion 👩‍💻\r\nAuto-GPT should be able to:\r\n\r...
# 84  _Context:_  Implement  **reflection**, a technique that allows generating more coherent and natural texts using pre-trained language models.\r\n\r\n_Problem or idea:_  Reflection is based on two articles that propose different methods to incorpor...
# 85  Auto-GPT is expensive to run due to GPT-4's API cost.\n\nWe could experiment with making it aware of this fact, by tracking tokens as they are used and converting to a dollar cost. \n\nThis could also be displayed to the user to help them be more...
# 86  **Auto-GPT currently pins it's Long-Term memory to the start of it's context window. It is able to manage this through commands.**\r\n\r\nAuto-GPT should be aware of it's short and long term memory usage so that it knows when something is doing t...

# %%
issues_body.reset_index(inplace=True)

# %%
print(issues_body)
# Out:
#     index  number
# 0       0     785  \
# 1       1     778
# 2       2     766
# 3       3     765
# 4       4     758
# 5       5     753
# 6       6     749
# 7       7     727
# 8       8     718
# 9       9     691
# 10     10     660
# 11     11     623
# 12     12     605
# 13     13     594
# 14     14     589
# 15     15     567
# 16     16     556
# 17     17     531
# 18     18     528
# 19     19     527
# 20     20     526
# 21     21     514
# 22     22     513
# 23     23     511
# 24     24     510
# 25     25     506
# 26     26     503
# 27     27     500
# 28     28     495
# 29     29     492
# 30     30     453
# 31     31     442
# 32     32     430
# 33     33     399
# 34     34     393
# 35     35     389
# 36     36     386
# 37     37     375
# 38     38     368
# 39     39     364
# 40     40     356
# 41     41     348
# 42     42     347
# 43     43     346
# 44     44     344
# 45     45     340
# 46     46     335
# 47     47     324
# 48     48     319
# 49     49     316
# 50     50     305
# 51     51     304
# 52     52     298
# 53     53     296
# 54     54     292
# 55     55     289
# 56     56     286
# 57     57     285
# 58     58     280
# 59     59     276
# 60     60     270
# 61     61     264
# 62     62     251
# 63     63     232
# 64     64     227
# 65     65     221
# 66     66     213
# 67     67     203
# 68     68     201
# 69     69     182
# 70     70     181
# 71     71     172
# 72     72     171
# 73     73     151
# 74     74     150
# 75     75     148
# 76     76     146
# 77     77     114
# 78     78      85
# 79     79      56
# 80     80      38
# 81     81      25
# 82     82      21
# 83     83      15
# 84     84      11
# 85     85       6
# 86     86       5
#
#                                                                                                                                                                                                                                                          body
# 0   ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now Auto-GPT does not provide any feedback on the goals and role etc.\r\n\r\nTo make sure it understood the assignment, it would be much better for ...
# 1   ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\n1. Run Auto-GPT as Docker image via VS Code.\r\n2. Provide goals for Auto-GPT.\r\n3. Write "y" command few times.\r\n4. Write "y -10" command f...
# 2   <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 3   <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 4   ### Background\r\nThis change was made to the `ai_config.py` file #185. However, based on a suggestion, the knowledge cutoff was directly added to the `prompt.txt` file. This aims to provide metadata to the AI, enhancing its search coordination a...
# 5   ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAdd `1/0` as alternative to `y/n`\n\n### Examples 🌈\n\nSo in\r\n`Continue (y/n)` and `Enter \'y\' to authorise command, \'y -N\' to run N continuous commands, \'n\' t...
# 6   Bitcoin handling for payments via bitcoin_utils.py\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to ...
# 7   ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nCurrently Auto-GPT writes the entire python or text file at once. If the file gets beyond a few paragraphs this starts to cause issues often time causing json parsing...
# 8   **EDIT: Please delete this PR as #697 seems to be a better solution**\r\n\r\nFixes #701 Credits belong to @Moomero\r\n\r\n### Background\r\nINVALID JSON errors happen very commonly. \r\n\r\n### Changes\r\nThis fix filters better and reduces the a...
# 9   Add additional clarification to error message as this is the first check of the model name.  An alternative approach would be to add a verification of the model before this is called.\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increa...
# 10  https://github.com/Torantulino/Auto-GPT/issues/656#issue-1660550311\r\n\r\nFix from updated line 20 from \r to \n\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the ...
# 11  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\n1. Set API Keys for OpenAI, Pinecone, and Eleven Labs, then set the smart model to gpt-3.5-turbo\r\n2. Start AutoGPT with the --gpt3only option\r\n3. Promp...
# 12  ### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, prior discussions, or links to relevant issues. -->\r\n\r\nThe aim of this PR is to make the use of Redis Stack beginner friendly ...
# 13                             Added some extra instructions to improve PR quality by addressing common pitfalls.\r\n\r\nI hope this will improve the quality of PRs and our efficiency in merging and reviewing them.\r\n\r\n@Torantulino what do you think?
# 14  ### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, prior discussions, or links to relevant issues. -->\r\nFork and clone instructions are not clear.\r\n\r\n### Changes\r\n\r\n<!-- D...
# 15                                                 ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nThat would be simply great instead of using OpenAI\n\n### Examples 🌈\n\n_No response_\n\n### Motivation 🔦\n\n_No response_
# 16  ### Background\r\n\r\n![image](https://user-images.githubusercontent.com/34168009/230755671-ddc951c8-3566-4426-8587-35a74d7f3186.png)\r\n\r\nIt's possible for your connection being closed causes AutoGPT to crash.\r\n\r\n### Changes\r\n\r\nWraps t...
# 17  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nbeable to understand the context of images\n\n### Examples 🌈\n\nlook on open ais showcase of gpt4 images context understanding and explainion\n\n### Motivation 🔦\n\nw...
# 18  ### System Awareness\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nBefore going out to look at the internet \r\nIt would be helpful if upon activation the AI took inventory of the system it was on and shared the ava...
# 19  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nI have locally installed Auto-GPT \r\nwithin the auto_gpt_workspace - I cloned the Auto-GPT repo\r\nI then asked the AI to look up the outstanding issues and begin to...
# 20  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nI wrote a python file that i am trying to get auto-gpt to utilize to scrape some data off the internet. To run the file, it requires the use of an argumen...
# 21  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nWhen crawling the web to do market research, a lot of links are sometimes just pdf documents. It would be great if Auto GPT had an inherent ability to parse those pdf...
# 22  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nAsk for Auto GPT to create a image, using sd in the .env\n\n### Current behavior 😯\n\nThe Auto-GPT got this error when tried to use generate_image command:...
# 23  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nAI Name: GameDev-GPT\r\n\r\nDescribe your AI's role:  For example, 'an AI designed to autonomously develop and run businesses with the sole goal of increas...
# 24  ### Background\r\n\r\nBig branch build on top of https://github.com/Torantulino/Auto-GPT/pull/372 (Redis implementation and memory refactor).\r\n\r\nWe need to improve modularity to scale the project so I created AutoGPT wrapper with the old main...
# 25  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAuto-GPT needs an inherent understanding of itself and the ability to connect with other Auto-GPT instances for collaboration. Once we get them talking they can figur...
# 26  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nReplace Google Search by an agency (coop of agents) to search both Google and pinecone memory from a prompt sent by autogpt to this agency \r\n\r\nUses multiple insta...
# 27  [![workerB](https://img.shields.io/endpoint?url=https%3A%2F%2Fworkerb.linearb.io%2Fv2%2Fbadge%2Fprivate%2FU2FsdGVkX12X34Yic5DPfPZec1mXyQl10i0d9YJs%2Fcollaboration.svg%3FcacheSeconds%3D60)](https://workerb.linearb.io/v2/badge/collaboration-page?ma...
# 28  ### Design Document\r\n https://docs.google.com/document/d/1pHtgK4OaFxy2POColR4nYJ3wemU4XLTEoxTLQunzaU0/edit?usp=sharing\r\n\r\n### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, pr...
# 29  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nCommand Generate Image "generate_image" is a great addition. However the image size is hardcoded,\r\nI propose the issue to make it controllable with an optional argu...
# 30  ### Background\r\n\r\nFelt I need more optionality at start-up: load last settings, load setting file from your history or create new settings. The need came out of running different "missions" with changes to the settings and prompts. Wanted an ...
# 31  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nLooking at Microsoft’s Jarvis and the improvement seen with refinement (where GPT is prompted after it’s response “did you do the last task correctly?”). Perhaps we c...
# 32  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAny thoughts on enabling auto-GPT to pick up where it left off after an error? It has done some noble work, but has never fully completed the tasks I've set for it be...
# 33  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nI'm not sure how to reproduce it, i've had it running trying to make a crossword generator for a while.\n\n### Current behavior 😯\n\nThe PLAN: output shows...
# 34  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nMy current challenge is it's hard to know how much it's costing me to run autoGPT for each session (for OPEN_AI in particular)\r\n\r\nIf I knew how much i...
# 35  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nUnsure, it randomly seems to produce this error. I've even given instructions that if the AI failed to parse the output then to reformat the input to a man...
# 36  ### Background\r\n\r\nI am using Auto-GPT search, browse and summarize code in another project and using this parallelization of single url summarization and summarizing multiple urls. \r\nAs most of the processing is IO bound I find this approac...
# 37  ### Background\r\n\r\nDevs and aspiring contributors frequently have dependency conflicts when trying to clone the repo and build dependencies for the first time. \r\n\r\nAdding an alternate requirements file:\r\n- Removes package versions, allow...
# 38  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\nN/A\r\n\r\n### Current behavior 😯\r\n\r\nAuto-GPT has limited test coverage, which makes it difficult to ensure that changes to the codebase do...
# 39  ### Background\r\nHey everyone, I saw some Twitter posts about people being able to install react apps and what not but didn't seem to be able to get it to work on my end. So, I took a stab at creating a module for working with react apps and add...
# 40  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nI'm wondering whether Auto-GPT, even if it's written in Python, could support other programming languages as well, since GPT is able to program in multiple ones.\r\n\...
# 41  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nImplement "Fully Air-Gapped Offline Auto-GPT" functionality that allows users to run Auto-GPT without any internet connection, relying on local models and...
# 42  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nLocal Models (LLaMA & its finetunes) now work in a fork of Auto-GPT, including with Pinecone Embeddings. See https://github.com/Torantulino/Auto-GPT/issue...
# 43  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\n1. Attach to a VirtualBox instance, give AI a default OS like ubuntu\r\n2. if AI decide to use computer: enter "screenshot-mouse/keyboard" loop, also ai can dump file...
# 44                                                                      I've added one other env variable to set tha pinecone index/table name from envs; previously it was a bit unclear how to configure pinecone and where does it get the table name from
# 45                                                                                                                                                                                                       Just for consistency, cost me ~5 seconds at setup 🤖
# 46                                                                                                                                                                                                                                                       None
# 47  Test, and make the needed changes to get this to work.\r\n\r\nIt may or may not work, there are still more things needed to get it working, but from testing it may work.\r\n\r\nPossible Suggestions:\r\n\r\n1) Combine the output of the custom mode...
# 48  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nUpgraded to latest version with Pinecone. Prompts that worked great yesterday now break constantly. Throwing the error:\r\n\r\nFailed to parse AI output, a...
# 49  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nIdea:\r\n\r\n- Add a `ai_settings` directory to contain yaml files in the form of `last_run_ai_settings.yaml`. This way we could create and share interesting or succe...
# 50  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nSummarize and then critique current approach and progress. I have done x,y and z. Progress p has been made toward the goal. Changing the approach is/is not warranted....
# 51  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now I am experimenting with a Wikidata Query command in auto-gpt on my repo: https://github.com/stefangrotz/Auto-GPT-Wikidata\r\n\r\nFeel free to jo...
# 52  So there are a few issues here that going into a larger design discussion so for now I re-worked the prompts, added a bit more option there and created a fallback output if the LLM decides to break format. \r\n\r\nThis also removes the LLM cycle ...
# 53  error During Requirement .txt execution \r\n\r\nOn raspberry pi 4b 8GB with Raspbian OS \r\n\r\nPython 3.7.3\r\npip3 install -r requirements.txt\r\n\r\nerror: \r\n  Could not find a version that satisfies the requirement python-dotenv==1.0.0 (fro...
# 54  Congratulation for this amazing Project \r\ni have local p retrained model through https://github.com/oobabooga/text-generation-webui\r\nusing their API in this format "\r\n\r\nimport requests\r\n\r\nresponse = requests.post("http://127.0.0.1:786...
# 55                                                                                                                                                                                                                                            Addresses #270
# 56  I've encountered the same problem as #101. GPT Thinks that `evaluate_code` will execute python:\r\n```\r\nCODEREVIEW-GPT THOUGHTS: Let's find some code to review and suggest improvements.\r\nREASONING: We need to search for files with common code...
# 57  Fixed the json_parser.py error by making chatgpt fix itself\r\n\r\ndef fix_and_parse_json(json_str: str, try_to_fix_with_gpt: bool = True):\r\n    json_schema = """\r\n    {\r\n    "command": {\r\n        "name": "command name",\r\n        "args"...
# 58  AutoGPT should be able to read GitHub issues, update its goals based on them, and respond as a commenter\n\n\nAutoGPT when you see this, please do the following: \n1. Find/get/create a list of all the usernames who forked this repo (Torantulino/A...
# 59  To improve this project, here are some suggestions:\r\n\r\nModularize the code: Separate the functions in commands.py into different modules based on their functionality. For example, you can create a module for file operations, another for memor...
# 60                                                                                                             If a user has multiple organizations linked to their OpenAI account they will be unable to use keys generated through different organizations.
# 61  You can use a class to encapsulate the behavior of the agents and remove the need for global variables. This will make the code more organized, and way less prone to error.\r\nYou can add error handing in case the API call to Open AI fails or the...
# 62  Hi,\r\n\r\nfeel free to close this again rightaway since I dont know if the is an issue at all.\r\n\r\nIn some demos when the AI creates a new instance, the new instance speaks with a female voice, an the conversation between the AI is easy to fo...
# 63  It appears that Auto-GPT is not working well with other character encodings. I am trying to use it on information written in Portuguese (Brazilian Portuguese) and sometimes it complains about "string indices must be integers" - I believe it is be...
# 64                                   AutoGPT was getting confused, and causing errors because it thought the keys for memory_ovr were strings instead of an integer. This better explains that the keys are actually indexes, which helps prevent this error.
# 65                                                                                                                        Moved all the ai functionality into one place - ai_functions.py.\r\n\r\nTo test: Run it for a little while, you will see no errors.
# 66                                                                                                                                                           I moved the memory functionality into it's own file, and made it a singleton. Works as expected.
# 67  Hi there,\r\nsince this is an evolving system, i think we should use collective experience, and like a tesla fleet, get better collectively\r\n### Proposal: Record Insights, Submit for review, Use Pinecone Embeddings\r\nif a task is requested and...
# 68  This change fixes an issue where we were writing the `string` as the `key` in `commit_memory`\r\n\r\nit re-designs perm memory to be a dictionary (key, value store) that seems to be a better fit for our use-case\r\n\r\n\r\ntest logs:\r\n\r\n```\r...
# 69  raise error.APIConnectionError(\r\nopenai.error.APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Cannot connect t...
# 70  Work in progress, but im Trying to give auto gpt a way to build, manage, and run command inside docker containers.\r\n\r\nThe goal are : \r\n- No need tp set up any dev environnment for Auto-Gpt to work\r\n- A way for Auto-GPT to run any commands...
# 71  Taking inspiration from the method that Langchain uses to instruct the bot on which tool to use, I've fleshed out each of the tools with a brief description to help the bot make a better decision. In testing it appears to work well and the bot se...
# 72                                                                                                                                                                                      What do you think of an option like this to enable language support ?
# 73  Hi there! Looked around the open issues but haven't seen this suggestion yet\r\n\r\nFirstly, I'd like to know that whatever is running is always logged (maybe that's addressed somewhere)\r\n\r\nSecondly , I'd like a "Cautious" Monitored Continuou...
# 74  ## Summary\r\n\r\nI propose a new feature called "Semi-Active Mode," which enables the AI to run in a semi-automated manner, seeking user assistance when it encounters uncertainty, confusion, or ambiguity. This feature combines the benefits of Co...
# 75  Love the project, wondering if you'd like to use vocode's interfaces for speech synthesis!\r\n- ports the existing ElevenLabs, gTTS, and StreamElements integrations\r\n- enables Azure voices: https://azure.microsoft.com/en-us/products/cognitive-s...
# 76  Hey everyone, I've been working on integrating Redis and a separate terminal-based CLI client with AutoGPT to enable asynchronous question-and-answer user interactions. This is just a draft PR, so any feedback or contributions are more than welco...
# 77  GPT already knows way too much stuff, there's no need to search the web for every little sub-task that comes up. For example, if you ask GPT what the rules for texas hold'em poker are, it knows and is able to detail it without any issues. When us...
# 78  This PR focuses on enhancing the file operations module by implementing the following changes:\r\n\r\n* Replacing the `os` and `os.path` modules with the `pathlib module`, which simplifies file and directory operations while providing better read...
# 79  Create a new command to dynamically expand capabilities.\r\n\r\n1. Identify a capability gap. e.g. if current weather/stock prices cannot be obtained from current Auto-GPT capabilities \r\n2. Provide a static list of known API libraries (or disco...
# 80  AutoGPT keeps exceeding the token limit by like 100 tokens every time I use it before it finishes it's task and can't handle the error\r\nTraceback (most recent call last):\r\n  File "/root/Auto-GPT/scripts/main.py", line 199, in <module>\r\n    ...
# 81  You can modify the code to accept a config file as input, and read the Chosen_Model flag to select the appropriate AI model. Here's an example of how to achieve this:\r\n\r\nCreate a sample config file named config.ini:\r\n\r\n[AI]\r\nChosen_Mode...
# 82                                                                                      It doesn't work?\r\n\r\n<img width="1440" alt="image" src="https://user-images.githubusercontent.com/6225438/229346042-a8687d08-8c4d-4094-8da4-b2300fb51732.png">\r\n
# 83  ## Idea 💡\r\nThe **ULTIMATE** achievement for this project would be if Auto-GPT was able to recursively improve itself. That, after-all, is how AGI is predicted by many to come about. \r\n\r\n## Suggestion 👩‍💻\r\nAuto-GPT should be able to:\r\n\r...
# 84  _Context:_  Implement  **reflection**, a technique that allows generating more coherent and natural texts using pre-trained language models.\r\n\r\n_Problem or idea:_  Reflection is based on two articles that propose different methods to incorpor...
# 85  Auto-GPT is expensive to run due to GPT-4's API cost.\n\nWe could experiment with making it aware of this fact, by tracking tokens as they are used and converting to a dollar cost. \n\nThis could also be displayed to the user to help them be more...
# 86  **Auto-GPT currently pins it's Long-Term memory to the start of it's context window. It is able to manage this through commands.**\r\n\r\nAuto-GPT should be aware of it's short and long term memory usage so that it knows when something is doing t...

# %%
issues_body.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Columns: 3 entries, index to body
# dtypes: int64(2), object(1)
# memory usage: 2.2+ KB

# %%
file_name = "issue_autogpt.txt"

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/mark/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Open the text file
with open(file_name, 'r', encoding="utf-8") as f:

  # Read the file and tokenize it into sentences
  text = f.read()
  sentences = nltk.sent_tokenize(text)

  # Convert the sentences into an array
  sentences_array = []
  for sentence in sentences:
    sentence = sentence.strip()  # Remove whitespace at the beginning and end of the sentence
    if sentence:  # Check if the sentence is not empty
      print(sentence)
      sentences_array.append(sentence)
# Out:
# ⚠️ Before you continue
# Check out our backlog, roadmap and join our discord to discuss what's going on
# If you need help, you can ask in the discussions section or in #tech-support
# Throughly search the existing issues before creating a new one
# ⚠️ Search for existing issues first ⚠️
# Please search the history to see if an issue already exists for the same problem.
# I have searched the existing issues, and there is no existing issue for my problem *
# Please provide a searchable summary of the issue in the title above ⬆️.
# ⚠️ SUPER-busy repo, please help the volunteer maintainers.
# The less time we spend here, the more time we spend building AutoGPT.
# Please help us help you:
#
# Does it work on stable branch (https://github.com/Torantulino/Auto-GPT/tree/stable)?
# Does it work on current master (https://github.com/Torantulino/Auto-GPT/tree/master)?
# Search for existing issues, "add comment" is tidier than "new issue"
# Ask on our Discord (https://discord.gg/autogpt)
# Provide relevant info:
# Provide commit-hash (git rev-parse HEAD gets it)
# If it's a pip/packages issue, provide pip version, python version
# If it's a crash, provide traceback.
# Which Operating System are you using?
# Please select the operating system you were using to run Auto-GPT when this problem occurred.
# Windows
# Which version of Auto-GPT are you using?
# Please select which version of Auto-GPT you were using when this issue occurred.
# If you downloaded the code from the releases page make sure you were using the latest code.
# If you weren't please try with the latest code.
# If installed with git you can run git branch to see which version of Auto-GPT you are running.
# Latest Release
# GPT-3 or GPT-4?
# If you are using Auto-GPT with --gpt3only, your problems may be caused by the limitations of GPT-3.5.
# GPT-3.5
# Steps to reproduce 🕹
# ⚠️ Issues that we can't reproduce will be closed.
# Current behavior 😯
# Describe what happens instead of the expected behavior.
# Expected behavior 🤔
# Describe what should happen.
# Your prompt 📝
# If applicable please provide the prompt you are using.
# Your prompt is stored in your ai_settings.yaml file.
# ```yaml
# # Paste your prompt here
# ```
#
# Your Logs 📒
# Please include the log showing your error and the command that caused it, if applicable.
# You can copy it from your terminal or from logs/activity.log.
# This will help us understand your issue better!
# Example
# ```log
# <insert your logs here>
# ```
#
# Fields marked with an asterisk (*) are required

# %%
for sentence1 in sentences_array:
    issues_body['body']=issues_body['body'].str.replace(sentence1,'')

# %%
print(sentences_array[10])
# Out:
# Please select which version of Auto-GPT you were using when this issue occurred.

# %%
issues_body.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Columns: 3 entries, index to body
# dtypes: int64(2), object(1)
# memory usage: 2.2+ KB

# %%
issues_body
# Out:
#     index  number
# 0       0     785  \
# 1       1     778
# 2       2     766
# 3       3     765
# 4       4     758
# 5       5     753
# 6       6     749
# 7       7     727
# 8       8     718
# 9       9     691
# 10     10     660
# 11     11     623
# 12     12     605
# 13     13     594
# 14     14     589
# 15     15     567
# 16     16     556
# 17     17     531
# 18     18     528
# 19     19     527
# 20     20     526
# 21     21     514
# 22     22     513
# 23     23     511
# 24     24     510
# 25     25     506
# 26     26     503
# 27     27     500
# 28     28     495
# 29     29     492
# 30     30     453
# 31     31     442
# 32     32     430
# 33     33     399
# 34     34     393
# 35     35     389
# 36     36     386
# 37     37     375
# 38     38     368
# 39     39     364
# 40     40     356
# 41     41     348
# 42     42     347
# 43     43     346
# 44     44     344
# 45     45     340
# 46     46     335
# 47     47     324
# 48     48     319
# 49     49     316
# 50     50     305
# 51     51     304
# 52     52     298
# 53     53     296
# 54     54     292
# 55     55     289
# 56     56     286
# 57     57     285
# 58     58     280
# 59     59     276
# 60     60     270
# 61     61     264
# 62     62     251
# 63     63     232
# 64     64     227
# 65     65     221
# 66     66     213
# 67     67     203
# 68     68     201
# 69     69     182
# 70     70     181
# 71     71     172
# 72     72     171
# 73     73     151
# 74     74     150
# 75     75     148
# 76     76     146
# 77     77     114
# 78     78      85
# 79     79      56
# 80     80      38
# 81     81      25
# 82     82      21
# 83     83      15
# 84     84      11
# 85     85       6
# 86     86       5
#
#                                                                                                                                                                                                                                                          body
# 0   ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now Auto-GPT does not provide any feedback on the goals and role etc.\r\n\r\nTo make sure it understood the assignment, it would be much better for ...
# 1   ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\n1. Run Auto-GPT as Docker image via VS Code.\r\n2. Provide goals for Auto-GPT.\r\n3. Write "y" command few times.\r\n4. Write "y -10" command f...
# 2   <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 3   <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 4   ### Background\r\nThis change was made to the `ai_config.py` file #185. However, based on a suggestion, the knowledge cutoff was directly added to the `prompt.txt` file. This aims to provide metadata to the AI, enhancing its search coordination a...
# 5   ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAdd `1/0` as alternative to `y/n`\n\n### Examples 🌈\n\nSo in\r\n`Continue (y/n)` and `Enter \'y\' to authorise command, \'y -N\' to run N continuous commands, \'n\' t...
# 6   Bitcoin handling for payments via bitcoin_utils.py\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to ...
# 7   ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nCurrently Auto-GPT writes the entire python or text file at once. If the file gets beyond a few paragraphs this starts to cause issues often time causing json parsing...
# 8   **EDIT: Please delete this PR as #697 seems to be a better solution**\r\n\r\nFixes #701 Credits belong to @Moomero\r\n\r\n### Background\r\nINVALID JSON errors happen very commonly. \r\n\r\n### Changes\r\nThis fix filters better and reduces the a...
# 9   Add additional clarification to error message as this is the first check of the model name.  An alternative approach would be to add a verification of the model before this is called.\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increa...
# 10  https://github.com/Torantulino/Auto-GPT/issues/656#issue-1660550311\r\n\r\nFix from updated line 20 from \r to \n\r\n\r\n<!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the ...
# 11  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\n1. Set API Keys for OpenAI, Pinecone, and Eleven Labs, then set the smart model to gpt-3.5-turbo\r\n2. Start AutoGPT with the --gpt3only option\r\n3. Promp...
# 12  ### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, prior discussions, or links to relevant issues. -->\r\n\r\nThe aim of this PR is to make the use of Redis Stack beginner friendly ...
# 13                             Added some extra instructions to improve PR quality by addressing common pitfalls.\r\n\r\nI hope this will improve the quality of PRs and our efficiency in merging and reviewing them.\r\n\r\n@Torantulino what do you think?
# 14  ### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, prior discussions, or links to relevant issues. -->\r\nFork and clone instructions are not clear.\r\n\r\n### Changes\r\n\r\n<!-- D...
# 15                                                 ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nThat would be simply great instead of using OpenAI\n\n### Examples 🌈\n\n_No response_\n\n### Motivation 🔦\n\n_No response_
# 16  ### Background\r\n\r\n![image](https://user-images.githubusercontent.com/34168009/230755671-ddc951c8-3566-4426-8587-35a74d7f3186.png)\r\n\r\nIt's possible for your connection being closed causes AutoGPT to crash.\r\n\r\n### Changes\r\n\r\nWraps t...
# 17  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nbeable to understand the context of images\n\n### Examples 🌈\n\nlook on open ais showcase of gpt4 images context understanding and explainion\n\n### Motivation 🔦\n\nw...
# 18  ### System Awareness\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nBefore going out to look at the internet \r\nIt would be helpful if upon activation the AI took inventory of the system it was on and shared the ava...
# 19  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nI have locally installed Auto-GPT \r\nwithin the auto_gpt_workspace - I cloned the Auto-GPT repo\r\nI then asked the AI to look up the outstanding issues and begin to...
# 20  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nI wrote a python file that i am trying to get auto-gpt to utilize to scrape some data off the internet. To run the file, it requires the use of an argumen...
# 21  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nWhen crawling the web to do market research, a lot of links are sometimes just pdf documents. It would be great if Auto GPT had an inherent ability to parse those pdf...
# 22  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nAsk for Auto GPT to create a image, using sd in the .env\n\n### Current behavior 😯\n\nThe Auto-GPT got this error when tried to use generate_image command:...
# 23  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nAI Name: GameDev-GPT\r\n\r\nDescribe your AI's role:  For example, 'an AI designed to autonomously develop and run businesses with the sole goal of increas...
# 24  ### Background\r\n\r\nBig branch build on top of https://github.com/Torantulino/Auto-GPT/pull/372 (Redis implementation and memory refactor).\r\n\r\nWe need to improve modularity to scale the project so I created AutoGPT wrapper with the old main...
# 25  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAuto-GPT needs an inherent understanding of itself and the ability to connect with other Auto-GPT instances for collaboration. Once we get them talking they can figur...
# 26  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nReplace Google Search by an agency (coop of agents) to search both Google and pinecone memory from a prompt sent by autogpt to this agency \r\n\r\nUses multiple insta...
# 27  [![workerB](https://img.shields.io/endpoint?url=https%3A%2F%2Fworkerb.linearb.io%2Fv2%2Fbadge%2Fprivate%2FU2FsdGVkX12X34Yic5DPfPZec1mXyQl10i0d9YJs%2Fcollaboration.svg%3FcacheSeconds%3D60)](https://workerb.linearb.io/v2/badge/collaboration-page?ma...
# 28  ### Design Document\r\n https://docs.google.com/document/d/1pHtgK4OaFxy2POColR4nYJ3wemU4XLTEoxTLQunzaU0/edit?usp=sharing\r\n\r\n### Background\r\n\r\n<!-- Provide a brief overview of why this change is being made. Include any relevant context, pr...
# 29  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nCommand Generate Image "generate_image" is a great addition. However the image size is hardcoded,\r\nI propose the issue to make it controllable with an optional argu...
# 30  ### Background\r\n\r\nFelt I need more optionality at start-up: load last settings, load setting file from your history or create new settings. The need came out of running different "missions" with changes to the settings and prompts. Wanted an ...
# 31  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nLooking at Microsoft’s Jarvis and the improvement seen with refinement (where GPT is prompted after it’s response “did you do the last task correctly?”). Perhaps we c...
# 32  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nAny thoughts on enabling auto-GPT to pick up where it left off after an error? It has done some noble work, but has never fully completed the tasks I've set for it be...
# 33  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nI'm not sure how to reproduce it, i've had it running trying to make a crossword generator for a while.\n\n### Current behavior 😯\n\nThe PLAN: output shows...
# 34  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nMy current challenge is it's hard to know how much it's costing me to run autoGPT for each session (for OPEN_AI in particular)\r\n\r\nIf I knew how much i...
# 35  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nUnsure, it randomly seems to produce this error. I've even given instructions that if the AI failed to parse the output then to reformat the input to a man...
# 36  ### Background\r\n\r\nI am using Auto-GPT search, browse and summarize code in another project and using this parallelization of single url summarization and summarizing multiple urls. \r\nAs most of the processing is IO bound I find this approac...
# 37  ### Background\r\n\r\nDevs and aspiring contributors frequently have dependency conflicts when trying to clone the repo and build dependencies for the first time. \r\n\r\nAdding an alternate requirements file:\r\n- Removes package versions, allow...
# 38  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\nN/A\r\n\r\n### Current behavior 😯\r\n\r\nAuto-GPT has limited test coverage, which makes it difficult to ensure that changes to the codebase do...
# 39  ### Background\r\nHey everyone, I saw some Twitter posts about people being able to install react apps and what not but didn't seem to be able to get it to work on my end. So, I took a stab at creating a module for working with react apps and add...
# 40  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nI'm wondering whether Auto-GPT, even if it's written in Python, could support other programming languages as well, since GPT is able to program in multiple ones.\r\n\...
# 41  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nImplement "Fully Air-Gapped Offline Auto-GPT" functionality that allows users to run Auto-GPT without any internet connection, relying on local models and...
# 42  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nLocal Models (LLaMA & its finetunes) now work in a fork of Auto-GPT, including with Pinecone Embeddings. See https://github.com/Torantulino/Auto-GPT/issue...
# 43  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\n1. Attach to a VirtualBox instance, give AI a default OS like ubuntu\r\n2. if AI decide to use computer: enter "screenshot-mouse/keyboard" loop, also ai can dump file...
# 44                                                                      I've added one other env variable to set tha pinecone index/table name from envs; previously it was a bit unclear how to configure pinecone and where does it get the table name from
# 45                                                                                                                                                                                                       Just for consistency, cost me ~5 seconds at setup 🤖
# 46                                                                                                                                                                                                                                                       None
# 47  Test, and make the needed changes to get this to work.\r\n\r\nIt may or may not work, there are still more things needed to get it working, but from testing it may work.\r\n\r\nPossible Suggestions:\r\n\r\n1) Combine the output of the custom mode...
# 48  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Steps to reproduce 🕹\n\nUpgraded to latest version with Pinecone. Prompts that worked great yesterday now break constantly. Throwing the error:\r\n\r\nFailed to parse AI output, a...
# 49  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nIdea:\r\n\r\n- Add a `ai_settings` directory to contain yaml files in the form of `last_run_ai_settings.yaml`. This way we could create and share interesting or succe...
# 50  ### Duplicates\n\n- [X] I have searched the existing issues\n\n### Summary 💡\n\nSummarize and then critique current approach and progress. I have done x,y and z. Progress p has been made toward the goal. Changing the approach is/is not warranted....
# 51  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now I am experimenting with a Wikidata Query command in auto-gpt on my repo: https://github.com/stefangrotz/Auto-GPT-Wikidata\r\n\r\nFeel free to jo...
# 52  So there are a few issues here that going into a larger design discussion so for now I re-worked the prompts, added a bit more option there and created a fallback output if the LLM decides to break format. \r\n\r\nThis also removes the LLM cycle ...
# 53  error During Requirement .txt execution \r\n\r\nOn raspberry pi 4b 8GB with Raspbian OS \r\n\r\nPython 3.7.3\r\npip3 install -r requirements.txt\r\n\r\nerror: \r\n  Could not find a version that satisfies the requirement python-dotenv==1.0.0 (fro...
# 54  Congratulation for this amazing Project \r\ni have local p retrained model through https://github.com/oobabooga/text-generation-webui\r\nusing their API in this format "\r\n\r\nimport requests\r\n\r\nresponse = requests.post("http://127.0.0.1:786...
# 55                                                                                                                                                                                                                                            Addresses #270
# 56  I've encountered the same problem as #101. GPT Thinks that `evaluate_code` will execute python:\r\n```\r\nCODEREVIEW-GPT THOUGHTS: Let's find some code to review and suggest improvements.\r\nREASONING: We need to search for files with common code...
# 57  Fixed the json_parser.py error by making chatgpt fix itself\r\n\r\ndef fix_and_parse_json(json_str: str, try_to_fix_with_gpt: bool = True):\r\n    json_schema = """\r\n    {\r\n    "command": {\r\n        "name": "command name",\r\n        "args"...
# 58  AutoGPT should be able to read GitHub issues, update its goals based on them, and respond as a commenter\n\n\nAutoGPT when you see this, please do the following: \n1. Find/get/create a list of all the usernames who forked this repo (Torantulino/A...
# 59  To improve this project, here are some suggestions:\r\n\r\nModularize the code: Separate the functions in commands.py into different modules based on their functionality. For example, you can create a module for file operations, another for memor...
# 60                                                                                                             If a user has multiple organizations linked to their OpenAI account they will be unable to use keys generated through different organizations.
# 61  You can use a class to encapsulate the behavior of the agents and remove the need for global variables. This will make the code more organized, and way less prone to error.\r\nYou can add error handing in case the API call to Open AI fails or the...
# 62  Hi,\r\n\r\nfeel free to close this again rightaway since I dont know if the is an issue at all.\r\n\r\nIn some demos when the AI creates a new instance, the new instance speaks with a female voice, an the conversation between the AI is easy to fo...
# 63  It appears that Auto-GPT is not working well with other character encodings. I am trying to use it on information written in Portuguese (Brazilian Portuguese) and sometimes it complains about "string indices must be integers" - I believe it is be...
# 64                                   AutoGPT was getting confused, and causing errors because it thought the keys for memory_ovr were strings instead of an integer. This better explains that the keys are actually indexes, which helps prevent this error.
# 65                                                                                                                        Moved all the ai functionality into one place - ai_functions.py.\r\n\r\nTo test: Run it for a little while, you will see no errors.
# 66                                                                                                                                                           I moved the memory functionality into it's own file, and made it a singleton. Works as expected.
# 67  Hi there,\r\nsince this is an evolving system, i think we should use collective experience, and like a tesla fleet, get better collectively\r\n### Proposal: Record Insights, Submit for review, Use Pinecone Embeddings\r\nif a task is requested and...
# 68  This change fixes an issue where we were writing the `string` as the `key` in `commit_memory`\r\n\r\nit re-designs perm memory to be a dictionary (key, value store) that seems to be a better fit for our use-case\r\n\r\n\r\ntest logs:\r\n\r\n```\r...
# 69  raise error.APIConnectionError(\r\nopenai.error.APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Cannot connect t...
# 70  Work in progress, but im Trying to give auto gpt a way to build, manage, and run command inside docker containers.\r\n\r\nThe goal are : \r\n- No need tp set up any dev environnment for Auto-Gpt to work\r\n- A way for Auto-GPT to run any commands...
# 71  Taking inspiration from the method that Langchain uses to instruct the bot on which tool to use, I've fleshed out each of the tools with a brief description to help the bot make a better decision. In testing it appears to work well and the bot se...
# 72                                                                                                                                                                                      What do you think of an option like this to enable language support ?
# 73  Hi there! Looked around the open issues but haven't seen this suggestion yet\r\n\r\nFirstly, I'd like to know that whatever is running is always logged (maybe that's addressed somewhere)\r\n\r\nSecondly , I'd like a "Cautious" Monitored Continuou...
# 74  ## Summary\r\n\r\nI propose a new feature called "Semi-Active Mode," which enables the AI to run in a semi-automated manner, seeking user assistance when it encounters uncertainty, confusion, or ambiguity. This feature combines the benefits of Co...
# 75  Love the project, wondering if you'd like to use vocode's interfaces for speech synthesis!\r\n- ports the existing ElevenLabs, gTTS, and StreamElements integrations\r\n- enables Azure voices: https://azure.microsoft.com/en-us/products/cognitive-s...
# 76  Hey everyone, I've been working on integrating Redis and a separate terminal-based CLI client with AutoGPT to enable asynchronous question-and-answer user interactions. This is just a draft PR, so any feedback or contributions are more than welco...
# 77  GPT already knows way too much stuff, there's no need to search the web for every little sub-task that comes up. For example, if you ask GPT what the rules for texas hold'em poker are, it knows and is able to detail it without any issues. When us...
# 78  This PR focuses on enhancing the file operations module by implementing the following changes:\r\n\r\n* Replacing the `os` and `os.path` modules with the `pathlib module`, which simplifies file and directory operations while providing better read...
# 79  Create a new command to dynamically expand capabilities.\r\n\r\n1. Identify a capability gap. e.g. if current weather/stock prices cannot be obtained from current Auto-GPT capabilities \r\n2. Provide a static list of known API libraries (or disco...
# 80  AutoGPT keeps exceeding the token limit by like 100 tokens every time I use it before it finishes it's task and can't handle the error\r\nTraceback (most recent call last):\r\n  File "/root/Auto-GPT/scripts/main.py", line 199, in <module>\r\n    ...
# 81  You can modify the code to accept a config file as input, and read the Chosen_Model flag to select the appropriate AI model. Here's an example of how to achieve this:\r\n\r\nCreate a sample config file named config.ini:\r\n\r\n[AI]\r\nChosen_Mode...
# 82                                                                                      It doesn't work?\r\n\r\n<img width="1440" alt="image" src="https://user-images.githubusercontent.com/6225438/229346042-a8687d08-8c4d-4094-8da4-b2300fb51732.png">\r\n
# 83  ## Idea 💡\r\nThe **ULTIMATE** achievement for this project would be if Auto-GPT was able to recursively improve itself. That, after-all, is how AGI is predicted by many to come about. \r\n\r\n## Suggestion 👩‍💻\r\nAuto-GPT should be able to:\r\n\r...
# 84  _Context:_  Implement  **reflection**, a technique that allows generating more coherent and natural texts using pre-trained language models.\r\n\r\n_Problem or idea:_  Reflection is based on two articles that propose different methods to incorpor...
# 85  Auto-GPT is expensive to run due to GPT-4's API cost.\n\nWe could experiment with making it aware of this fact, by tracking tokens as they are used and converting to a dollar cost. \n\nThis could also be displayed to the user to help them be more...
# 86  **Auto-GPT currently pins it's Long-Term memory to the start of it's context window. It is able to manage this through commands.**\r\n\r\nAuto-GPT should be aware of it's short and long term memory usage so that it knows when something is doing t...

# %%
issues_body.to_csv('issue_body_after_remove.csv')

# %%
issues_body.head()
# Out:
#    index  number
# 0      0     785  \
# 1      1     778
# 2      2     766
# 3      3     765
# 4      4     758
#
#                                                                                                                                                                                                                                                         body
# 0  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now Auto-GPT does not provide any feedback on the goals and role etc.\r\n\r\nTo make sure it understood the assignment, it would be much better for ...
# 1  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\n1. Run Auto-GPT as Docker image via VS Code.\r\n2. Provide goals for Auto-GPT.\r\n3. Write "y" command few times.\r\n4. Write "y -10" command f...
# 2  <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 3  <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 4  ### Background\r\nThis change was made to the `ai_config.py` file #185. However, based on a suggestion, the knowledge cutoff was directly added to the `prompt.txt` file. This aims to provide metadata to the AI, enhancing its search coordination a...

# %%
import re

# Extract the issue number from the body column and add it as a new column
#issues_body['Issue_number'] = issues_body['body'].str.extract(r'(\d+)')

# Remove the checkbox from the body column
issues_body['body'] = issues_body['body'].str.replace('- \[X\] ', '')

# Extract the section headers and their corresponding text into separate columns
headers = ['Steps to reproduce', 'Current behavior', 'Expected behavior', 'Your prompt']
for header in headers:
    issues_body[header] = issues_body['body'].str.extract(rf'{header}.*?\n(.*?)\n\n', flags=re.DOTALL | re.IGNORECASE)
    issues_body['body'] = issues_body['body'].str.replace(rf'{header}.*?\n(.*?)\n\n', '')

# Reorder the columns
issues_body = issues_body[['index', 'number', 'Steps to reproduce', 'Current behavior', 'Expected behavior', 'Your prompt', 'body']]
# Out:
# /tmp/ipykernel_179828/186626598.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body['body'] = issues_body['body'].str.replace('- \[X\] ', '')
# /tmp/ipykernel_179828/186626598.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body[header] = issues_body['body'].str.extract(rf'{header}.*?\n(.*?)\n\n', flags=re.DOTALL | re.IGNORECASE)
# /tmp/ipykernel_179828/186626598.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body['body'] = issues_body['body'].str.replace(rf'{header}.*?\n(.*?)\n\n', '')
# /tmp/ipykernel_179828/186626598.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body[header] = issues_body['body'].str.extract(rf'{header}.*?\n(.*?)\n\n', flags=re.DOTALL | re.IGNORECASE)
# /tmp/ipykernel_179828/186626598.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body['body'] = issues_body['body'].str.replace(rf'{header}.*?\n(.*?)\n\n', '')
# /tmp/ipykernel_179828/186626598.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body[header] = issues_body['body'].str.extract(rf'{header}.*?\n(.*?)\n\n', flags=re.DOTALL | re.IGNORECASE)
# /tmp/ipykernel_179828/186626598.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body['body'] = issues_body['body'].str.replace(rf'{header}.*?\n(.*?)\n\n', '')
# /tmp/ipykernel_179828/186626598.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body[header] = issues_body['body'].str.extract(rf'{header}.*?\n(.*?)\n\n', flags=re.DOTALL | re.IGNORECASE)
# /tmp/ipykernel_179828/186626598.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_body['body'] = issues_body['body'].str.replace(rf'{header}.*?\n(.*?)\n\n', '')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 16
#      13     issues_body['body'] = issues_body['body'].str.replace(rf'{header}.*?\n(.*?)\n\n', '')
#      15 # Reorder the columns
# ---> 16 issues_body = issues_body[['index', 'number', 'Steps to reproduce', 'Current behavior', 'Expected behavior', 'Your prompt', 'body']]
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/autogpt_DA/lib/python3.11/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['number'] not in index"

# %%
issues_body.head()
# Out:
#    index Issue_number Steps to reproduce Current behavior Expected behavior
# 0      0            2                NaN              NaN               NaN  \
# 1      1            1                NaN              NaN               NaN
# 2      2            8                NaN              NaN               NaN
# 3      3            8                NaN              NaN               NaN
# 4      4          185                NaN              NaN               NaN
#
#   Your prompt
# 0         NaN  \
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#                                                                                                                                                                                                                                                         body
# 0  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Summary 💡\r\n\r\nRight now Auto-GPT does not provide any feedback on the goals and role etc.\r\n\r\nTo make sure it understood the assignment, it would be much better for ...
# 1  ### Duplicates\r\n\r\n- [X] I have searched the existing issues\r\n\r\n### Steps to reproduce 🕹\r\n\r\n1. Run Auto-GPT as Docker image via VS Code.\r\n2. Provide goals for Auto-GPT.\r\n3. Write "y" command few times.\r\n4. Write "y -10" command f...
# 2  <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 3  <!-- 📢 Announcement\r\nWe've recently noticed an increase in pull requests focusing on combining multiple changes. While the intentions behind these PRs are appreciated, it's essential to maintain a clean and manageable git history. To ensure the...
# 4  ### Background\r\nThis change was made to the `ai_config.py` file #185. However, based on a suggestion, the knowledge cutoff was directly added to the `prompt.txt` file. This aims to provide metadata to the AI, enhancing its search coordination a...
